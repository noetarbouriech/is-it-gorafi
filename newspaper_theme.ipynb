# %% [markdown]
# <a href="https://colab.research.google.com/github/noetarbouriech/is-it-gorafi/blob/main/newspaper_theme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Newspaper category?
#
# Text classification model for recognizing Gorafi news articles by comparing with Figaro news article.

# %% [markdown]
# ## Dependencies installation

# %%
# !git clone https://github.com/noetarbouriech/is-it-gorafi.git
# Out:
# Cloning into 'is-it-gorafi'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 5), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 185.49 KiB | 3.64 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !pip install datasets transformers huggingface_hub evaluate scikit-learn optimum[exporters]
# !apt-get install git-lfs
# Out:
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.28.1)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting optimum[exporters]
#   Downloading optimum-1.24.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from optimum[exporters]) (2.6.0+cu124)
# Collecting onnx (from optimum[exporters])
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxruntime (from optimum[exporters])
#   Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from optimum[exporters]) (1.0.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11->optimum[exporters])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->optimum[exporters]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11->optimum[exporters]) (1.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx->optimum[exporters]) (4.25.6)
# Collecting coloredlogs (from onnxruntime->optimum[exporters])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->optimum[exporters]) (25.2.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm->optimum[exporters]) (0.21.0+cu124)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->optimum[exporters])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->optimum[exporters]) (3.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm->optimum[exporters]) (11.1.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 14.4 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 6.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.9 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 76.8 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 78.2 MB/s eta 0:00:00
# Downloading optimum-1.24.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 26.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, onnx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, coloredlogs, onnxruntime, nvidia-cusolver-cu12, datasets, optimum, evaluate
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed coloredlogs-15.0.1 datasets-3.4.1 dill-0.3.8 evaluate-0.4.3 humanfriendly-10.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.17.0 onnxruntime-1.21.0 optimum-1.24.0 xxhash-3.5.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %% [markdown]
# # Is it gorafi ?

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline, TrainingArguments, Trainer

SEED = 42

# Load dataset
dataset = load_dataset("csv", data_files="is-it-gorafi/dataset.csv")

# Map category labels to numerical values
categories = ["culture", "sciences", "sports", "société", "politique"]

# Encode categories
def encode_category(example):
    example["label"] = categories.index(example["category"])
    return example

dataset = dataset.map(encode_category)

# Split train/test data
train_test_split = dataset["train"].train_test_split(test_size=0.2, seed=SEED, shuffle=True)
train_dataset = train_test_split['train']
test_dataset = train_test_split['test']

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("Geotrend/distilbert-base-en-fr-cased")
model = AutoModelForSequenceClassification.from_pretrained("Geotrend/distilbert-base-en-fr-cased", num_labels=len(categories))

# Tokenization function
def tokenize_function(examples):
    return tokenizer(examples["title"], padding="max_length", truncation=True)

# Tokenize dataset
tokenized_train = train_dataset.map(tokenize_function, batched=True)
tokenized_test = test_dataset.map(tokenize_function, batched=True)

# Training arguments
training_args = TrainingArguments(
    output_dir="test_trainer",
    eval_strategy="epoch",
    save_strategy="epoch",
    num_train_epochs=3,
    learning_rate=2e-5,
    weight_decay=0.1,
    per_device_train_batch_size=16,
    load_best_model_at_end=True,  # Load best model based on validation metrics
    greater_is_better=True,  # If True, selects the model with highest accuracy
    report_to="none",
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
)

# Train model
trainer.train()
trainer.evaluate()

# Initialize the classification pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Analyze dataset
def analyze_category(batch):
    titles = batch['title']
    predictions = classifier(titles)

    # Convert predictions to category
    predicted_categories = [categories[int(pred["label"].split("_")[-1])] for pred in predictions]

    return {'predicted_category': predicted_categories}

# Apply the classification function
test_dataset = test_dataset.map(analyze_category, batched=True)

nb_examples = min(100, len(test_dataset))
accuracy = 0

# Evaluate predictions
for i in range(nb_examples):
    example = test_dataset[i]
    print(f"Title: {example['title']}")
    print(f"Predicted category: {example['predicted_category']} | Actual category: {categories[example['label']]}")

    if example['predicted_category'] == categories[example['label']]:
        accuracy += 1

print("Accuracy =", accuracy / nb_examples)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/4102 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/277M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at Geotrend/distilbert-base-en-fr-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/3281 [00:00<?, ? examples/s]
# Map:   0%|          | 0/821 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='618' max='618' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [618/618 08:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.745808</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.670382</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.777100</td>
#       <td>0.666600</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='103' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 00:12]
#     </div>
# Device set to use cuda:0
# Map:   0%|          | 0/821 [00:00<?, ? examples/s]
# Title: «J’ai construit une écologie du réel», les indiscrétions duFigaro Magazine
# Predicted category: sciences | Actual category: politique
# Title: Un surfeur rate complètement sa descente en oubliant d’envoyer de la poudreuse sur les skieurs
# Predicted category: société | Actual category: sports
# Title: Ligue des nations : un choc Italie-Allemagne, Ronaldo au Danemark, le nouveau cycle espagnol... Tout sur les autres quarts de finale
# Predicted category: sports | Actual category: sports
# Title: Thales Alenia Space présente Halo, première étape de la future station orbitale Lunar Gateway
# Predicted category: sciences | Actual category: sciences
# Title: Jean-Paul Delevoye a oublié de préciser qu’il allait toucher 5% de toutes les retraites des Français
# Predicted category: politique | Actual category: politique
# Title: Facebook : Il partage un article d’astrophysique auquel il ne comprend rien
# Predicted category: sciences | Actual category: sciences
# Title: Marlène Schiappa met sa couverture Playboy aux enchères pour rembourser le Fonds Marianne
# Predicted category: culture | Actual category: politique
# Title: L’édition 2018 du Monopoly aura pour thème les époux Balkany
# Predicted category: culture | Actual category: culture
# Title: Rugby : la France obtient le droit de perdre la Coupe du monde à domicile en 2023
# Predicted category: sports | Actual category: sports
# Title: Un serrurier confesse qu’à 64 ans il n’aura plus la force d’arnaquer les clients
# Predicted category: société | Actual category: société
# Title: Coupe du Monde – le Qatar promet de couper la clim dans les caves où vivent ses ouvriers
# Predicted category: sports | Actual category: sports
# Title: Véhicules incendiés, tir de Flash-Ball… Dans les Alpes, la guerre est déclarée entre taxis et VTC
# Predicted category: société | Actual category: société
# Title: Il hésite à officialiser leur relation malgré leurs trois enfants et l’achat d’un pavillon
# Predicted category: société | Actual category: société
# Title: «L’Afghanistan est devenu une prison à ciel ouvert»: Fawzia Koofi, la colère froide d’une combattante
# Predicted category: société | Actual category: culture
# Title: Loi narcotrafic : le «dossier coffre» français, un «copier-coller» du modèle belge
# Predicted category: société | Actual category: société
# Title: «Les radicaux, ce sont les baleiniers» : rencontre avec Paul Watson, corsaire, conservateur et insoumis
# Predicted category: société | Actual category: sciences
# Title: «Le fossé s’est creusé entre les joueurs et les médias»: comment les Bleus gèrent leur communication
# Predicted category: sports | Actual category: sports
# Title: Pénurie de profs – Les établissements autorisés à recruter les élèves qui ont la moyenne comme contractuels
# Predicted category: société | Actual category: société
# Title: Roland-Garros : Gaël Monfils gêné par « de la poussière orange » sur le court
# Predicted category: sports | Actual category: sports
# Title: In Memoriam : Michel Barnier (2024-2024)
# Predicted category: politique | Actual category: politique
# Title: Toulouse : l’incendie criminel d’une concession Tesla revendiqué par des anarchistes
# Predicted category: société | Actual category: société
# Title: La campagne électorale d’Anne Hidalgo relancée après un commentaire positif posté sur Facebook
# Predicted category: politique | Actual category: politique
# Title: Retour de Mbappé, choc en Croatie, hommage à Giroud... 5 questions sur le (court) rassemblement des Bleus
# Predicted category: sports | Actual category: sports
# Title: SpaceX : nouvelle déception pour la mégafusée Starship d’Elon Musk
# Predicted category: sciences | Actual category: sciences
# Title: 5 précédents cas dans lequel le gouvernement a dû avoir recours au 49.3 pour faire passer une loi
# Predicted category: politique | Actual category: politique
# Title: «Le fossé s’est creusé entre les joueurs et les médias»: comment les Bleus gèrent leur communication
# Predicted category: sports | Actual category: sports
# Title: Foot : pour deux matchs, Marcelo Bielsa sélectionne... 36 joueurs avec l’Uruguay
# Predicted category: sports | Actual category: sports
# Title: Censure médiatique – Pourquoi Gulli refuse toujours de donner la parole à Eric Zemmour
# Predicted category: politique | Actual category: politique
# Title: Ukraine : l’Élysée dément le déplacement de Macron avec Zelensky et Starmer à Washington, évoqué par la porte-parole du gouvernement
# Predicted category: politique | Actual category: politique
# Title: 81% des Français affirment ne pas être ici pour rigoler
# Predicted category: société | Actual category: sciences
# Title: D’après une étude américaine, toutes les bonnes choses de la vie seraient cancérigènes
# Predicted category: sciences | Actual category: sciences
# Title: Inéligibilité de Marine Le Pen : le Conseil constitutionnel se penche sur la question de l’exécution provisoire
# Predicted category: politique | Actual category: société
# Title: Incendies, inondations, sécheresse, séismes... La ville de Los Angeles deviendra-t-elle bientôt inhabitable ?
# Predicted category: sciences | Actual category: sciences
# Title: Pour 3 millions d’euros, McKinsey conseille au gouvernement de mettre de l’eau sur les incendies
# Predicted category: politique | Actual category: politique
# Title: Au Sahara occidental, Gérard Larcher poursuit le rapprochement avec le Maroc sur fond de crise franco-algérienne
# Predicted category: politique | Actual category: politique
# Title: Desloverboyproxénètes à l’enfer des foyers de l’ASE, le livre choc sur le «tsunami» de la prostitution des adolescentes
# Predicted category: société | Actual category: société
# Title: Présidentielle 2027 : Martine Aubry souhaite une union «large» de la gauche, mais «sans Jean-Luc Mélenchon»
# Predicted category: politique | Actual category: politique
# Title: Koundé, Konaté, Tchouameni... L’arrivée élégante des Bleus à Clairefontaine ce lundi
# Predicted category: sports | Actual category: sports
# Title: Tour de France – Les coureurs autorisés à tirer au LBD pour éloigner la foule
# Predicted category: sports | Actual category: sports
# Title: Le gouvernement va fabriquer en urgence des idées de gauche pour les hôpitaux
# Predicted category: politique | Actual category: politique
# Title: L'artiste allemand Anselm Kiefer se sent «menacé» par l'extrême droite
# Predicted category: culture | Actual category: culture
# Title: Écologie : Un rapport préconise l’extermination de l’espèce humaine
# Predicted category: sciences | Actual category: sciences
# Title: Pablo Ladam, étudiant à Sciences Po, dénonce une « justice parallèle » à l’œuvre au sein de l’école
# Predicted category: société | Actual category: société
# Title: « Ceci n’est pas une pomme » par Sibeth Ndiaye
# Predicted category: culture | Actual category: politique
# Title: Agnès Buzyn regrette de ne pas avoir fait alliance avec l’abstention
# Predicted category: politique | Actual category: politique
# Title: Test – Combien valent vos organes sur le marché noir ?
# Predicted category: sciences | Actual category: société
# Title: Altercation Trump-Zelensky : pour Jean-Philippe Tanguy (RN), le président ukrainien «n’a pas été humilié»
# Predicted category: politique | Actual category: politique
# Title: Selon une étude, les gens qui disent « c’était mieux avant » étaient beaucoup mieux avant
# Predicted category: sciences | Actual category: société
# Title: «Une chance sur 44» : l’astéroïde 2024 YR4 menace de percuter la Terre dans sept ans
# Predicted category: sciences | Actual category: sciences
# Title: À Lyon, l’Auditorium Maurice Ravel fête son demi-siècle en fanfare
# Predicted category: culture | Actual category: culture
# Title: Louis Laugier, DG de la police nationale : «Nous frappons un point de deal toutes les trente minutes»
# Predicted category: société | Actual category: société
# Title: Des extraterrestres élisent la Terre comme site potentiel pour l’enfouissement de leurs déchets nucléaires
# Predicted category: sciences | Actual category: sciences
# Title: Christophe Castaner promet que les LBD « feront preuve de pédagogie » avec les yeux des manifestants
# Predicted category: politique | Actual category: politique
# Title: Comment Mayotte s’est trouvée en pleine trajectoire du cyclone Chido
# Predicted category: sciences | Actual category: sciences
# Title: Paris 2024 – Anne Hidalgo envisage de garder Tony Estanguet en vie après la fin des Jeux
# Predicted category: sports | Actual category: société
# Title: Noël : faut-il mentir à ses enfants ou leur révéler que le Père Noël est un mâle blanc de plus de 50 ans ?
# Predicted category: société | Actual category: société
# Title: Affiche anti-Hanouna : LFI prisonnière de son jusqu’au-boutisme
# Predicted category: société | Actual category: politique
# Title: En soutien à Emmanuel Macron chaque Français invité à se gifler lui-même ce soir à 20:00
# Predicted category: politique | Actual category: politique
# Title: Particulièrement exposée, Cannes est pionnière face au risque de tsunami
# Predicted category: société | Actual category: sciences
# Title: Mondiaux de ski acrobatique : «Le travail paye toujours», savoure Perrine Laffont après son 6e titre mondial
# Predicted category: sports | Actual category: sports
# Title: Grèves RATP : 17 utilisateurs en panique après la fermeture de la ligne 3 bis
# Predicted category: société | Actual category: société
# Title: Pourquoi le réchauffement climatique favorise la survenue d’incendies catastrophiques à Los Angeles
# Predicted category: sciences | Actual category: sciences
# Title: Après son retour sur Terre, Thomas Pesquet bloqué dans des bouchons sur l’A6
# Predicted category: sciences | Actual category: société
# Title: Il se fait tatouer en espérant avoir enfin une personnalité
# Predicted category: société | Actual category: culture
# Title: Jeux Olympiques : Chaos attendu au 100×4 mètres nage libre
# Predicted category: sports | Actual category: sports
# Title: L’abstention détrône Jean-Jacques Goldman comme personnalité préférée des Français
# Predicted category: politique | Actual category: société
# Title: Six Nations : «Cette équipe de France est meilleure que celle de 2023», salue Fabien Galthié
# Predicted category: sports | Actual category: sports
# Title: Assemblée : une résolution appelant à la libération de Boualem Sansal adoptée en commission, la gauche s’abstient
# Predicted category: politique | Actual category: politique
# Title: «Horizons rime avec soumission» : Philippe refuse d’interdire totalement le voile dans le sport, Bardella dénonce des «propos ambigus»
# Predicted category: sports | Actual category: politique
# Title: La Fabrique du mensonge: ciné-club exceptionnel duFigaro Histoirele 18 mars
# Predicted category: société | Actual category: sciences
# Title: Municipales – Pour raisons sanitaires, le gouvernement annule les élections et place ses députés à la tête des mairies
# Predicted category: politique | Actual category: politique
# Title: Sebastian Coe, David Lappartient, Kirsty Coventry, Juan Antonio Samaranch Jr... Qui sera le prochain président du Comité international olympique ?
# Predicted category: sports | Actual category: sports
# Title: Hockey sur glace : en raison de l’absence de bagarre générale, le match Briançon-Epinal sera reporté
# Predicted category: sports | Actual category: sports
# Title: En moyenne, nous passons deux ans de notre vie à chercher un objet qui est juste devant nos yeux
# Predicted category: sciences | Actual category: sciences
# Title: Prophétique ou provocateur : des catholiques français évoquent leur rapport avec le pape François
# Predicted category: société | Actual category: société
# Title: Étude – L’amour durerait en réalité 3 minutes et non 3 ans
# Predicted category: société | Actual category: sciences
# Title: La position Laurent Voulzy rentre dans le Kamasutra
# Predicted category: politique | Actual category: culture
# Title: Voile dans le sport : pour Élisabeth Borne, la «responsabilité» de l’interdire revient aux fédérations sportives
# Predicted category: sports | Actual category: politique
# Title: La science est formelle : « Il est venu le temps des cathédrales »
# Predicted category: sciences | Actual category: sciences
# Title: Jean-Luc Mélenchon répondra à Gérard Larcher ce soir lors d’un freestyle dans Planète Rap
# Predicted category: culture | Actual category: politique
# Title: « J’essaie de ne pas trop en faire » par Hatem Ben Arfa, en train de préparer le petit déj de Didier Deschamps
# Predicted category: sports | Actual category: sports
# Title: Abominations, de Lionel Shriver: corrosif et irrespectueux
# Predicted category: politique | Actual category: culture
# Title: SpaceX compte envoyer de nouveaux équipages privés vers l'ISS
# Predicted category: sciences | Actual category: sciences
# Title: Elections: Jean Lassalle a bel et bien obtenu ses 500 bouteilles de pinard
# Predicted category: politique | Actual category: politique
# Title: «Il n’est pas populaire, mais y’a du monde quand même» : Macron, une visite apaisée au Salon de l’agriculture
# Predicted category: politique | Actual category: politique
# Title: Le Gorafi envisage d’ajouter des articles à ses titres
# Predicted category: culture | Actual category: culture
# Title: Paris – il tente un rodéo urbain avec un Vélib’, 0 mort
# Predicted category: société | Actual category: société
# Title: Affaire Bayou : «Je n’en ai pas dormi pendant des nuits», raconte Marine Tondelier
# Predicted category: politique | Actual category: politique
# Title: 5 remèdes de grand-mère pour agrandir votre pénis
# Predicted category: société | Actual category: sciences
# Title: Elle ne sait pas si elle est encore amoureuse après qu’il lui a parlé de crypto-monnaies
# Predicted category: société | Actual category: société
# Title: Pour qu’on parle à nouveau d’elle, la Flamme olympique se présentera aux législatives
# Predicted category: sports | Actual category: politique
# Title: Gestes barrières – Les garagistes à nouveau autorisés à vous saluer en vous tendant le poignet
# Predicted category: société | Actual category: société
# Title: «Il est crucial de répondre à l’obscurantisme»: l’université Aix-Marseille accueille des chercheurs américains qui fuient Trump
# Predicted category: sciences | Actual category: sciences
# Title: «Certains peuvent le vivre comme une véritable perte d’identité»: la transmission des exploitations, un défi pour l’agriculture française
# Predicted category: sciences | Actual category: société
# Title: Couvre-feu à 18h : Ce qu’il fallait retenir des annonces de Jean Castex
# Predicted category: politique | Actual category: politique
# Title: Selon le CNC, il faudrait douze comédies racistes supplémentaires pour sauver le cinéma français
# Predicted category: culture | Actual category: culture
# Title: Procès Le Scouarnec : l’ex-femme nie avoir eu connaissance des déviances de l’accusé
# Predicted category: société | Actual category: société
# Title: Une étude révèle pourquoi votre ex n’en a strictement plus rien à faire de vous
# Predicted category: sciences | Actual category: sciences
# Title: Présidence des Républicains: Laurent Wauquiez et Bruno Retailleau se lancent à la conquête des militants
# Predicted category: politique | Actual category: politique
# Title: En manque de doses de vaccin, le gouvernement va injecter des applaudissements aux soignants
# Predicted category: société | Actual category: politique
# Accuracy = 0.73

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline, TrainingArguments, Trainer

SEED=42

# Load dataset
dataset = load_dataset("csv", data_files="is-it-gorafi/dataset.csv")
dataset = dataset.map(lambda x: {"is_gorafi": int(x["is_gorafi"])})

# Split train/test data
train_test_split = dataset["train"].train_test_split(test_size=0.2, seed=SEED, shuffle=True)
train_dataset = train_test_split['train']
test_dataset = train_test_split['test']

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("Geotrend/distilbert-base-en-fr-cased")
model = AutoModelForSequenceClassification.from_pretrained("Geotrend/distilbert-base-en-fr-cased")

# Tokenization function
def tokenize_function(examples):
    return tokenizer(examples["title"], padding="max_length", truncation=True)

# Tokenize dataset
tokenized_datasets = train_dataset.map(tokenize_function, batched=True)
tokenized_test_datasets = test_dataset.map(tokenize_function, batched=True)

# Rename label column
tokenized_datasets = tokenized_datasets.rename_column("is_gorafi", "label")
tokenized_test_datasets = tokenized_test_datasets.rename_column("is_gorafi", "label")

# Training arguments
training_args = TrainingArguments(
    output_dir="test_trainer",
    eval_strategy="epoch",
    save_strategy="epoch",
    num_train_epochs=3,
    learning_rate=2e-5,  # Reduced learning rate
    weight_decay=0.1,  # L2 regularization
    per_device_train_batch_size=16,  # Increase batch size
    load_best_model_at_end=True,  # Load best model based on validation metrics
    greater_is_better=True,  # If True, selects the model with highest accuracy
    report_to="none",  # Disable logging to Weights & Biases
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets,
    eval_dataset=tokenized_test_datasets
)

# Train model
trainer.train()
trainer.evaluate()

# Initialize the sentiment analysis pipeline
nlp_ara = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Process dataset
def analyze_sentiment(batch):
    titles = batch['title']
    predictions = nlp_ara(titles)  # Run sentiment analysis on the batch of titles

    # Prepare the output
    predicted_is_gorafi = [1 if prediction['label'] == 'LABEL_1' else 0 for prediction in predictions]

    # Return the batch with the added 'predicted_is_gorafi' field
    return {'predicted_is_gorafi': predicted_is_gorafi}

# Apply the sentiment analysis function to the dataset
test_dataset = test_dataset.map(analyze_sentiment, batched=True)

nb_examples = min(100, len(test_dataset))
accuracy = 0

# Show some results - accessing the first few entries correctly
for i in range(nb_examples):  # Show the first 5 examples
    example = test_dataset[i]  # Access each example
    print(f"Title: {example['title']}")
    print(f"Predicted is_gorafi: {example['predicted_is_gorafi']} | Actual is_gorafi: {example['is_gorafi']}")
    if example['predicted_is_gorafi'] == example['is_gorafi']:
      accuracy+=1

print("Accuracy = ", accuracy / nb_examples)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/4102 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/277M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at Geotrend/distilbert-base-en-fr-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/3281 [00:00<?, ? examples/s]
# Map:   0%|          | 0/821 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='618' max='618' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [618/618 08:13, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.228933</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.234918</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.281700</td>
#       <td>0.238929</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='103' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 00:11]
#     </div>
# Device set to use cuda:0
# Map:   0%|          | 0/821 [00:00<?, ? examples/s]
# Title: «J’ai construit une écologie du réel», les indiscrétions duFigaro Magazine
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Un surfeur rate complètement sa descente en oubliant d’envoyer de la poudreuse sur les skieurs
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Ligue des nations : un choc Italie-Allemagne, Ronaldo au Danemark, le nouveau cycle espagnol... Tout sur les autres quarts de finale
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Thales Alenia Space présente Halo, première étape de la future station orbitale Lunar Gateway
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Jean-Paul Delevoye a oublié de préciser qu’il allait toucher 5% de toutes les retraites des Français
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Facebook : Il partage un article d’astrophysique auquel il ne comprend rien
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Marlène Schiappa met sa couverture Playboy aux enchères pour rembourser le Fonds Marianne
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: L’édition 2018 du Monopoly aura pour thème les époux Balkany
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Rugby : la France obtient le droit de perdre la Coupe du monde à domicile en 2023
# Predicted is_gorafi: 0 | Actual is_gorafi: True
# Title: Un serrurier confesse qu’à 64 ans il n’aura plus la force d’arnaquer les clients
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Coupe du Monde – le Qatar promet de couper la clim dans les caves où vivent ses ouvriers
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Véhicules incendiés, tir de Flash-Ball… Dans les Alpes, la guerre est déclarée entre taxis et VTC
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Il hésite à officialiser leur relation malgré leurs trois enfants et l’achat d’un pavillon
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: «L’Afghanistan est devenu une prison à ciel ouvert»: Fawzia Koofi, la colère froide d’une combattante
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Loi narcotrafic : le «dossier coffre» français, un «copier-coller» du modèle belge
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: «Les radicaux, ce sont les baleiniers» : rencontre avec Paul Watson, corsaire, conservateur et insoumis
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: «Le fossé s’est creusé entre les joueurs et les médias»: comment les Bleus gèrent leur communication
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title:
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Couvre-feu à 18h : Ce qu’il fallait retenir des annonces de Jean Castex
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Selon le CNC, il faudrait douze comédies racistes supplémentaires pour sauver le cinéma français
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Procès Le Scouarnec : l’ex-femme nie avoir eu connaissance des déviances de l’accusé
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: Une étude révèle pourquoi votre ex n’en a strictement plus rien à faire de vous
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Title: Présidence des Républicains: Laurent Wauquiez et Bruno Retailleau se lancent à la conquête des militants
# Predicted is_gorafi: 0 | Actual is_gorafi: False
# Title: En manque de doses de vaccin, le gouvernement va injecter des applaudissements aux soignants
# Predicted is_gorafi: 1 | Actual is_gorafi: True
# Accuracy =  0.93

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
model = AutoModelForSequenceClassification.from_pretrained("Geotrend/distilbert-base-en-fr-cased")
x = model.config

print(model.config_class)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at Geotrend/distilbert-base-en-fr-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <class 'transformers.models.distilbert.configuration_distilbert.DistilBertConfig'>

# %% [markdown]
# ## Using our model

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# Extract true labels and predictions
true_labels = [example['is_gorafi'] for example in test_dataset]
predicted_labels = [example['predicted_is_gorafi'] for example in test_dataset]

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

print("Confusion Matrix:")
print(cm)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-9e2034c2aa2b> in <cell line: 0>()
#       3 # Extract true labels and predictions
#       4 true_labels = [example['is_gorafi'] for example in test_dataset]
# ----> 5 predicted_labels = [example['predicted_is_gorafi'] for example in test_dataset]
#       6
#       7 # Compute confusion matrix
#
# <ipython-input-6-9e2034c2aa2b> in <listcomp>(.0)
#       3 # Extract true labels and predictions
#       4 true_labels = [example['is_gorafi'] for example in test_dataset]
# ----> 5 predicted_labels = [example['predicted_is_gorafi'] for example in test_dataset]
#       6
#       7 # Compute confusion matrix
#
# KeyError: 'predicted_is_gorafi'

# %% [markdown]
# ### Using model with a sentence provided by us

# %%
test_title = "L’Arbitre Oublie Son Sifflet, Les Joueurs Continuent Depuis 3 Jours"

prediction_gorafi = nlp_ara(test_title)

# Check confidence score and adjust prediction logic
label_gorafi = prediction_gorafi[0]['label']
score_gorafi = prediction_gorafi[0]['score']

if score_gorafi < 0.6:  # Set a threshold for confidence score
    predicted_is_gorafi = 0  # If confidence is low, treat it as not is_gorafi
else:
    predicted_is_gorafi = 1 if label_gorafi == 'LABEL_1' else 0

prediction_category = classifier(test_title)

# Extract label and confidence score
label_category = prediction_category[0]['label']
score_category = prediction_category[0]['score']

# Map label to category
predicted_cat = categories[int(label_category.split("_")[-1])]

# Apply confidence threshold
if score_category < 0.4:  # Set a threshold for confidence score
    predicted_cat = predicted_cat + "(uncertain)"  # If confidence is low, mark as uncertain


print(f"Title: {test_title}")

print(f"Predicted: is gorafi {predicted_is_gorafi} with confidence score: {score_gorafi}")
print(f"Predicted: category {predicted_cat} with confidence score: {score_category}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8f74ab411e97> in <cell line: 0>()
#       1 test_title = "L’Arbitre Oublie Son Sifflet, Les Joueurs Continuent Depuis 3 Jours"
#       2
# ----> 3 prediction_gorafi = nlp_ara(test_title)
#       4
#       5 # Check confidence score and adjust prediction logic
#
# NameError: name 'nlp_ara' is not defined

# %% [markdown]
# ## Exporting our tokenizer and model in ONNX format

# %%
from optimum.exporters.onnx import main_export

onnx_output_dir = "onnx_model"

main_export(
    model_name_or_path="test_trainer/checkpoint-357",
    task="text-classification",
    output=onnx_output_dir,
)
print(f"ONNX model exported to {onnx_output_dir}/ folder")
# Out:
# ONNX model exported to onnx_model/
